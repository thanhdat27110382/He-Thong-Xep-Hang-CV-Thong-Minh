# %%
import pandas as pd

# %%
# Đọc file CSV đã crawl
input_csv = "D:/BaiDoAnChuyenNganh3/Automated-Resume-Ranking-System-main/csvfiles/crawlcv/finaldata2links_examples.csv"  # Thay bằng tên file thực tế của bạn
df = pd.read_csv(input_csv)

# %%
# Hàm chuẩn hóa và gộp Category theo danh sách ngành nghề
def normalize_category(category):
    category = category.lower().strip()

    # Accounting & Finance
    accounting_finance = {"Accounting", "Accounting Assistant", "Accounting Clerk", "Accounting Manager", "Accounts Payable", 
                          "Accounts Payable/Receivable", "Accounts Receivable", "Actuary", "Audit Associate", "Auditor", 
                          "Bank Manager Resume", "Bank Teller", "Banking", "Billing Specialist", "Bookkeeper", "Branch Manager Resume", 
                          "Business", "Business Analyst", "Business Intelligence", "Certified Public Accountant / CPA", "Claims Adjuster", 
                          "Collections Representative", "Collector", "Consultant", "Controller", "Credit Analyst", "Entry-Level Accounting", 
                          "Entry-Level Business Analyst", "Entry-Level Financial Analyst", "Finance", "Finance Manager", "Financial Advisor", 
                          "Financial Analyst", "Financial Planning & Analysis (FP&A)", "Goldman Sachs", "Internal Auditor", "Investment Banking", 
                          "Loan Officer", "Loan Processor", "McKinsey", "Medical Billing", "Mortgage Underwriter", "Personal Banker", 
                          "Private Equity", "Program Analyst", "Senior Accountant", "Staff Accountant", "Tax Accountant", "Tax Preparer", 
                          "Trader", "Treasurer", "Venture Capital"}
    if category in [x.lower() for x in accounting_finance]:
        return "Accounting & Finance"

    # Construction
    construction = {"Architecture", "CNC Machinist", "Construction", "Construction Manager", "Construction Project Manager", 
                    "Construction Superintendent", "Contractor", "Forklift Operator", "General Labour", "HVAC", "Landscape Architecture", 
                    "Machinist", "Maintenance", "Pipefitter", "Welder"}
    if category in [x.lower() for x in construction]:
        return "Construction"

    # Creative & Cultural Fields
    creative_cultural = {"3D Artist", "Acting", "Animator", "Art Director", "Artist", "Artist CV", "Beginner Acting", 
                         "Brand Ambassador", "Cinematographer", "Content Creator", "Copywriter", "Creative Director", "Creative Writer", 
                         "Dance", "Dance Teacher", "DJ", "Editor", "Event Planner", "Fashion", "Fashion Designer", "Fashion Stylist", 
                         "Film", "Filmmaker", "Freelance Photographer", "Freelance Writer", "Game Design", "Graphic Designer", "Hair Stylist", 
                         "Illustrator", "Instructional Designer", "Interior Design", "Interpreter", "Makeup Artist", "Model", "Music", 
                         "Photographer", "Product Designer", "Production Assistant", "Production Coordinator", "Senior Graphic Designer", 
                         "Stage Manager", "Technical Writer", "Theatre", "Translator", "UX Designer & UI Developer", "Video Editor", 
                         "Video Producer", "Videographer", "Web Designer", "Writer"}
    if category in [x.lower() for x in creative_cultural]:
        return "Creative & Cultural Fields"

    # Education & Learning
    education_learning = {"Academic", "Academic Advisor", "Adjunct Professor", "Art Teacher", "Assistant Headmaster", "Babysitter", 
                          "Basketball Coach", "Camp Counselor", "Child Care", "Coaching", "College Graduate", "College Student", 
                          "CV Examples For Teens", "CV For College Application", "Education & Teaching Jobs", "Elementary Teacher", 
                          "Engineering Student", "English Teacher", "ESL Teacher", "Graduate Assistant", "Graduate School/CV For PhD Programs", 
                          "Harvard", "High School Student", "Instructional Designer", "Law School", "Law Student", "Librarian", "Library Assistant", 
                          "Math Teacher", "MBA Application", "Medical Student", "New Teacher", "Paraprofessional", "PhD", "Pre-Med", 
                          "Preschool Teacher", "Professor", "Research Assistant", "Resume For College Freshman", "Resume For High School Graduate", 
                          "Resume For Internship", "Scholarship", "School Counselor", "School Principal", "Secondary School Teacher", "Sorority", 
                          "Special Education Teacher", "Student-Athlete Resume", "Substitute Teacher", "Teacher", "Teacher’s Aide", 
                          "Teaching Assistant", "Tutor", "Yoga Teacher"}
    if category in [x.lower() for x in education_learning]:
        return "Education & Learning"

    # Engineering & Scientific
    engineering_scientific = {"Audio Engineer", "Automation Engineer", "AWS", "Bioinformatics", "Biologist", "Biomedical Engineering", 
                              "Business", "Business Intelligence", "Cable Technician", "Chemical Engineer", "Chemist", "Civil Engineering", 
                              "CNC Machinist", "Computer Engineering", "Computer Science", "Consultant", "Data Engineer", "Database Developer", 
                              "Electrical Engineering", "Electronic Technician", "Engineering", "Engineering Internship", "Engineering Manager", 
                              "Engineering Project Manager", "Entry-Level Mechanical Engineering", "Environmental Science", "HVAC", 
                              "Industrial Engineer", "IT Technician", "Lab Assistant", "Lab Technician", "Machine Learning", "Manufacturing Engineer", 
                              "Mechanical Engineering", "Process Engineer", "Project Engineer", "Python Developer", "Quality Control", "Quality Engineer", 
                              "Salesforce", "Salesforce Admin", "Science", "Software Engineer", "Solution Architect", "Supply Chain", "Systems Engineer", 
                              "Technical Writer"}
    if category in [x.lower() for x in engineering_scientific]:
        return "Engineering & Scientific"

    # Food Service
    food_service = {"Baker", "Banquet Server", "Bar Manager", "Barback", "Barista", "Bartender", "Catering", "Chef", "Chick-fil-A", 
                    "Commis Waiter", "Cook", "Culinary", "Dishwasher", "Fast Food", "Food Service", "Kitchen Hand", "Kitchen Manager", 
                    "Line Cook", "McDonald's", "Music Teacher", "Pastry Chef", "Prep Cook", "Restaurant", "Restaurant General Manager", 
                    "Restaurant Manager", "Restaurant Server", "Server", "Sous Chef", "Starbucks", "Subway", "Waiter", "Waitress"}
    if category in [x.lower() for x in food_service]:
        return "Food Service"

    # Hospitality Travel & Transportation
    hospitality_travel = {"Bus Driver", "Delivery Driver", "Dispatcher", "Driver", "Event Manager", "Flight Attendant", "Front Desk", 
                          "Hospitality", "Hostess", "Hotel General Manager", "Hotel Manager", "Lifeguard", "Logistics", "Night Auditor", 
                          "Receptionist", "School Bus Driver", "Tour Guide", "Travel Agent", "Truck Driver", "Uber Driver"}
    if category in [x.lower() for x in hospitality_travel]:
        return "Hospitality Travel & Transportation"

    # Information Technology (IT)
    it = {".NET Developer", "3D Artist", "Active Directory", "Agile Coach", "Agile Project Manager", "Android Developer", "Angular Developer", 
          "AngularJS", "Animator", "AWS", "Azure DevOps", "Back-End Developer", "Big Data", "Bioinformatics", "Business", "Cloud Engineer", 
          "Computer Engineering", "Computer Science", "Computer Technician", "Consultant", "CRM", "Cyber Security", "Data Analyst", 
          "Data Center Technician", "Data Scientist", "Database Developer", "Desktop Support", "DevOps", "Engineering Student", "Entry Level IT", 
          "Entry-Level Software Engineer", "Front End Developer", "Full Stack Developer", "Game Design", "Informatica", "Information Security Analyst", 
          "iOS Developer", "IT (Information Technology)", "IT Director", "IT Help Desk", "IT Manager", "IT Project Manager", "IT Specialist", 
          "IT Support", "IT Technician", "Java Developer", "Junior Java Developer", "Junior Web Developer", "Machine Learning", "Network Administrator", 
          "Network Engineer", "Programmer", "Python Developer", "QA", "QA Tester", "React Developer", "Salesforce", "Salesforce Admin", "Scrum Master", 
          "SDET", "Senior Java Developer", "Senior Software Engineer", "Software Engineer", "Software Engineer Intern", "Solution Architect", 
          "SQL Developer", "SSRS", "System Administrator", "System Analyst", "Tableau Developer", "Technical Project Manager", "Technical Support", 
          "UI Developer", "UX Designer", "UX Designer & UI Developer", "UX Researcher", "Web Designer", "Web Developer", "WordPress Developer", "Writer"}
    if category in [x.lower() for x in it]:
        return "Information Technology (IT)"

    # Law Enforcement & Emergency Services
    law_enforcement = {"Correctional Officer", "Criminal Justice", "Firefighter", "Military To Civilian", "Peace Corps", "Police Officer", "Security Guard"}
    if category in [x.lower() for x in law_enforcement]:
        return "Law Enforcement & Emergency Services"

    # Legal
    legal = {"Associate Attorney", "Attorney", "Business", "Consultant", "Contract Administrator", "General Counsel", "Law Clerk", "Law School", 
             "Legal", "Legal Assistant", "Legal Intern", "Legal Secretary", "Paralegal"}
    if category in [x.lower() for x in legal]:
        return "Legal"

    # Maintenance & Repair
    maintenance_repair = {"Automotive Technician", "Building Maintenance", "Carpenter", "Cleaner", "Contractor", "Custodian", "Electrician", 
                          "Electrician Apprentice", "Facility Manager", "Forklift Operator", "General Labour", "Handyman", "Housekeeping", "HVAC", 
                          "Janitor", "Journeyman Electrician", "Landscaping", "Machinist", "Maintenance", "Maintenance Manager", "Maintenance Supervisor", 
                          "Maintenance Technician", "Mechanic", "Painter", "Pipefitter", "Plumber", "Technician", "Welder"}
    if category in [x.lower() for x in maintenance_repair]:
        return "Maintenance & Repair"

    # Management & Leadership
    management_leadership = {"Account Executive", "Account Manager", "Accounting Intern", "Accounting Manager", "Assistant Manager", "Assistant Project Manager", 
                             "Bank Manager Resume", "Branch Manager Resume", "Business", "Business Consultant", "Business Development", "Business Manager", 
                             "Business Owner", "CEO", "CFO", "Chief Of Staff", "CIO", "Communications Director", "Construction Manager", "Consultant", 
                             "COO - Chief Operations Officer", "Customer Service Manager", "Customer Success Manager", "Director", "Director Of Operations", 
                             "District Manager", "Entrepreneur", "Executive", "Facility Manager", "Finance Manager", "General Manager", "IT Director", 
                             "IT Manager", "IT Project Manager", "Maintenance Manager", "Management Consultant", "Manager", "Marketing Director", 
                             "Marketing Executive", "MBA Application", "Nurse Manager", "Operations Manager", "Operations Supervisor", "Plant Manager", 
                             "Product Manager", "Product Marketing Manager", "Production Manager", "Program Manager", "Project Coordinator", "Project Manager", 
                             "Relationship Manager", "Restaurant General Manager", "Safety Manager", "Senior Project Manager", "Shift Manager", "Sports Management", 
                             "Stage Manager", "Store Manager", "Supervisor", "Team Leader", "Technical Program Manager", "Training Manager", "Warehouse Manager"}
    if category in [x.lower() for x in management_leadership]:
        return "Management & Leadership"

    # Media And Entertainment
    media_entertainment = {"Journalism", "Producer", "Public Relations"}
    if category in [x.lower() for x in media_entertainment]:
        return "Media And Entertainment"

    # Manufacturing & Warehousing
    manufacturing_warehousing = {"Amazon", "Assembly Line Worker", "Logistics Coordinator", "Machine Operator", "Manufacturing", "Material Handler", 
                                 "Mechanic", "Production", "Production Worker", "Shipping And Receiving", "Stocker", "Supply Chain", "Supply Chain Manager", 
                                 "Warehouse", "Warehouse Associate", "Warehouse Manager", "Warehouse Supervisor"}
    if category in [x.lower() for x in manufacturing_warehousing]:
        return "Manufacturing & Warehousing"

    # Medicine Healthcare & Wellbeing
    medicine_healthcare = {"Aged Care", "Athletic Trainer", "Barber", "BCBA", "Budtender", "Caregiver", "Case Manager", "Charge Nurse", 
                           "Clinical Research Coordinator", "CNA", "Cosmetology", "Dental Assistant", "Dental Hygiene", "Dental Receptionist", 
                           "Dentist", "Dietary Aide", "Dietician", "Disability Support Worker", "Doctor", "Emergency Nurse", "EMT/Paramedic", 
                           "Entry-Level Nurse", "Esthetician", "Experienced Nurse", "First Year Teacher", "Hair Stylist", "Healthcare", 
                           "Healthcare Administration", "Home Care Assistant", "Hospital Volunteer", "ICU Nurse", "Labor And Delivery Nurse", 
                           "LPN", "LVN", "Makeup Artist", "Massage Therapist", "Med-Surg Nurse", "Medical", "Medical Administrative Assistant", 
                           "Medical Assistant", "Medical Billing", "Medical Coder", "Medical Receptionist", "Medical School", "Medical Scribe", 
                           "Medical Technologist", "Mental Health Counselor", "Nail Technician", "New Grad Nursing", "NICU Nurse", "Nurse Manager", 
                           "Nurse Practitioner", "Nursing", "Nursing Student", "Occupational Therapy", "Operating Room Nurse", "Optician", "Optometrist", 
                           "Patient Care Technician", "PCA", "Pediatric Nurse", "Personal Assistant", "Personal Trainer", "Pharmacist", "Pharmacy Assistant", 
                           "Pharmacy Intern", "Pharmacy Technician", "Phlebotomy", "Physical Therapy", "Physical Therapy Aide", "Physicial Assistant", 
                           "Physician", "Pre-Med", "PSW", "Psychologist", "Public Health", "Radiologic Technologist", "RBT", "Registered Nurse", 
                           "Respiratory Therapist", "School Nurse", "School Psychologist", "Sonographer", "Speech Pathologist", "Student Esthetician", 
                           "Surgical Tech", "Telemetry Nurse", "Therapist", "Travel Nurse", "Veterinarian", "Veterinary Assistant", "Veterinary Receptionist", 
                           "Veterinary Technician", "Yoga Teacher"}
    if category in [x.lower() for x in medicine_healthcare]:
        return "Medicine Healthcare & Wellbeing"

    # Office & Administrative
    office_admin = {"Administrative Assistant", "Administrative Coordinator", "Business", "Business Administration", "Clerical", "Consultant", 
                    "Data Entry", "Diversity And Inclusion", "Entry-Level Administrative Assistant", "Entry-Level Human Resources", "Executive Assistant", 
                    "Federal", "HR Assistant", "HR Business Partner", "HR Coordinator", "HR Generalist", "HR Manager", "HR Specialist", "Human Resources", 
                    "Legal Assistant", "Medical Office Manager", "Medical Receptionist", "Office Administrator", "Office Assistant", "Office Clerk", 
                    "Office Manager", "Public Relations", "Recruiter", "Resident Assistant", "School Secretary", "Secretary", "Social Work", 
                    "Talent Acquisition Specialist", "Virtual Assistant"}
    if category in [x.lower() for x in office_admin]:
        return "Office & Administrative"

    # Real Estate
    real_estate = {"Assistant Property Manager", "Leasing Agent", "Leasing Consultant", "Property Manager", "Real Estate"}
    if category in [x.lower() for x in real_estate]:
        return "Real Estate"

    # Retail & Customer Service
    retail_customer = {"Apple", "Budtender", "Buyer", "Car Salesman", "Cashier", "Collections Representative", "Customer Service", 
                       "Customer Service Associate", "Customer Service Manager", "Customer Success Manager", "Grocery Store", "Help Desk", 
                       "Hostess", "Hotel Front Desk", "Insurance Agent", "Merchandiser", "Pharma Sales", "Relationship Manager", "Retail", 
                       "Retail Assistant", "Retail Assistant Manager", "Retail Manager", "Retail Sales Associate", "Sales Associate", 
                       "Service Advisor", "Store Manager", "Visual Merchandising", "Walmart"}
    if category in [x.lower() for x in retail_customer]:
        return "Retail & Customer Service"

    # Sales & Marketing
    sales_marketing = {"Art Director", "Brand Ambassador", "Brand Manager", "Business", "Business Development", "Business Development Representative", 
                       "Buyer", "Call Center", "Call Center Supervisor", "Communications Director", "Communications Specialist", "Community Manager", 
                       "Consultant", "Contract Specialist", "Digital Marketing", "Digital Marketing Manager", "Ecommerce", "Entry-Level Marketing", 
                       "Hostess", "Market Research", "Marketing", "Marketing Coordinator", "Marketing Director", "Marketing Executive", "Marketing Intern", 
                       "Marketing Manager", "Merchandiser", "Product Development", "Product Owner", "Purchasing", "Purchasing Agent", "Retail Sales Associate", 
                       "Sales", "Sales Assistant", "Sales Associate", "Sales Consultant", "Sales Director", "Sales Manager", "Sales Representative", 
                       "SEO", "Social Media", "Social Media Intern", "Vendor Management", "Video Editor", "Videographer", "Visual Merchandising", "Writer"}
    if category in [x.lower() for x in sales_marketing]:
        return "Sales & Marketing"

    # Teaching & Learning
    teaching_learning = {"Art Teacher", "Assistant Headmaster", "Camp Counselor", "Child Care", "Coaching", "Corporate Trainer", "Dance Teacher", 
                         "Elementary Teacher", "English Teacher", "ESL Teacher", "Instructional Designer", "Librarian", "Math Teacher", "Mentor", 
                         "Paraeducator", "Paraprofessional", "Preschool Teacher", "School Counselor", "School Psychologist", "Secondary School Teacher", 
                         "Special Education Teacher", "Substitute Teacher", "Teacher", "Teacher’s Aide", "Teaching Assistant", "Trainer", "Tutor", "Yoga Teacher"}
    if category in [x.lower() for x in teaching_learning]:
        return "Teaching & Learning"

    # Other
    other = {"American Resume", "ATS-Friendly CV", "Bad CV", "Best Buy", "Best CV", "Biodata Format", "Boyfriend", "Business Consultant", 
             "Business Owner", "Career Change", "CV With No Experience", "Deloitte", "Dog Walker", "Elon Musk", "Entry-Level", "Eye-Catching CV", 
             "Federal", "GameStop", "GIS", "Goldman Sachs", "Google", "Grammarly", "Hair Stylist", "Harvard", "Home Depot", "Hostess", "Insurance Agent", 
             "Internal Position", "Lifeguard", "Makeup Artist", "Mall Santa", "McKinsey", "Mentor", "Microsoft", "Military To Civilian", "Nanny", 
             "Nonprofit", "Pastor", "Plain Text CV", "Political Science", "Professional Pilot", "Resume For Mid-Career", "Resume For Senior-Level", 
             "SAP", "Security Officer", "Self-Employed", "Soccer", "Sports", "Spotify", "Stay-At-Home Mom", "Student-Athlete Resume", "Targeted Resume", 
             "Technical", "The Perfect CV", "TikTok", "Traditional CV", "Undergraduate", "UPS", "Video CV", "Volunteer Coordinator", "YouTuber Resume"}
    if category in [x.lower() for x in other]:
        return "Other"

    return "Other"  # Mặc định nếu không khớp với bất kỳ nhóm nào

# Xóa các dòng trùng lặp hoàn toàn (nếu có)
df = df.drop_duplicates(subset=["resume_str", "resume_html", "Category"], keep="first")

# Sắp xếp lại ID từ 1 đến hết
df["ID"] = range(1, len(df) + 1)

# Áp dụng hàm chuẩn hóa Category
df["Category"] = df["Category"].apply(normalize_category)

# Sắp xếp theo ID
df = df.sort_values("ID")

# %%
df.head(50)
# Out:
#     ID                                         resume_str  \
# 0    1  Gerard Levine\nCertified Public Accountant\n+1...
# 1    2  Brian Watkins\nAccounting Assistant\nbrian.wat...
# 2    3  Roman Arkell Accounting Clerk (781) 984-9624 r...
# 3    4  Lukas Summers\nlukas.summers@mail.us\n(646) 62...
# 4    5  Moe Money\nAccounts Payable Specialist\n555-69...
# 5    6  Penny Payments\npennypaymentszety@gmail.com\n6...
# 6    7  Penny Payments\npennypaymentszety@gmail.com\n6...
# 7    8  Tario Burki Actuary (305) 239-2096 tariozburki...
# 8    9  Michelle Price\nSenior Audit Associate\n(903) ...
# 9   10  Richard Schmidt\nJunior Internal Auditor\nrich...
# 10  11  George Rainwater\nBank Manager\n(205) 354-6799...
# 11  12  Gary K. Mathewson\nCertified Bank Teller (CBT)...
# 12  13  Royce Lopez\nBanker\n(916) 566-6124\nroycezlop...
# 13  14  Michael Blessing\nBilling Specialist\n(832) 46...
# 14  15  Matt Peterson\nBookkeeper\n(832) 830-3600\nmat...
# ...

# %%
# Lưu vào file CSV mới
output_csv = "D:/BaiDoAnChuyenNganh3/Automated-Resume-Ranking-System-main/csvfiles/crawlcv/xulydata2linksclean.csv"
df.to_csv(output_csv, index=False, encoding="utf-8")
print(f"Dữ liệu đã được sắp xếp và gộp Category, lưu vào file: {output_csv}")
print(f"Tổng số dòng sau khi xử lý: {len(df)}")
# Out:
# Dữ liệu đã được sắp xếp và gộp Category, lưu vào file: D:/BaiDoAnChuyenNganh3/Automated-Resume-Ranking-System-main/csvfiles/crawlcv/xulydata2linksclean.csv
# Tổng số dòng sau khi xử lý: 643
